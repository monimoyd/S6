# %% [markdown]
# <a href="https://colab.research.google.com/github/monimoyd/S6/blob/master/DNN_Pytorch_Architecture_Changes_Step5_l2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **l2 regularization on  base code:**
#
# **Target**: In this step, I have applied l2 regularization (0.001) on setp5 notebook of assignment 5, removed dropout.
#
# **Result**: I have got Train accuracy: 99.46   validation accuracy: 99.37   Number of parameters: 8,582
#
# **Analysis**: The validation accuracy after l2 regulization has slighly reduced from base model. But if I include dropout also, my observation is that validation accuracy reduces to around 99.20. This is because two different regulization technique does not go well

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 14, 3, padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(14),
        ) # Input=28, Output=28, rf=3
        self.conv2 = nn.Sequential(
            nn.Conv2d(14, 14, 3, padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(14)            
        ) # Input=28, Output=28, rf=5

        self.pool1= nn.MaxPool2d(2, 2) # Input=28, Output=14, rf=6

        self.conv3 = nn.Sequential(
            nn.Conv2d(14, 14, 3, padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(14)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(14, 14, 3, padding=1, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(14)
       )

        self.pool2= nn.MaxPool2d(2, 2) # Input=14, Output=7, rf=16

        self.conv5 = nn.Sequential(
            nn.Conv2d(14, 14, 3, padding=0, bias=False),
            nn.ReLU(),
            nn.BatchNorm2d(14)
        )


       
        self.conv6 = nn.Sequential(
            nn.Conv2d(14, 10, 3, padding=0, bias=False),
        ) # Input=5, Output=3, rf=32

        self.global_avgpool = nn.AdaptiveAvgPool2d(1)  # Input=3, Output=1, rf=40
      
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.pool1(x)
        x = self.conv3(x)
        x = self.conv4(x)

        x = self.pool2(x)
        x = self.conv5(x)
        x = self.conv6(x)
               
        x = self.global_avgpool(x)
        x = x.view(-1, 10)
        return F.log_softmax(x)

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net().to(device)
summary(model, input_size=(1, 28, 28))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 14, 28, 28]             126
#               ReLU-2           [-1, 14, 28, 28]               0
#        BatchNorm2d-3           [-1, 14, 28, 28]              28
#             Conv2d-4           [-1, 14, 28, 28]           1,764
#               ReLU-5           [-1, 14, 28, 28]               0
#        BatchNorm2d-6           [-1, 14, 28, 28]              28
#          MaxPool2d-7           [-1, 14, 14, 14]               0
#             Conv2d-8           [-1, 14, 14, 14]           1,764
#               ReLU-9           [-1, 14, 14, 14]               0
#       BatchNorm2d-10           [-1, 14, 14, 14]              28
#            Conv2d-11           [-1, 14, 14, 14]           1,764
#              ReLU-12           [-1, 14, 14, 14]               0
#       BatchNorm2d-13           [-1, 14, 14, 14]              28
#         MaxPool2d-14             [-1, 14, 7, 7]               0
#            Conv2d-15             [-1, 14, 5, 5]           1,764
#              ReLU-16             [-1, 14, 5, 5]               0
#       BatchNorm2d-17             [-1, 14, 5, 5]              28
#            Conv2d-18             [-1, 10, 3, 3]           1,260
# AdaptiveAvgPool2d-19             [-1, 10, 1, 1]               0
# ================================================================
# Total params: 8,582
# Trainable params: 8,582
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.66
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.70
# ----------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %%
#torch.manual_seed(11)
batch_size = 128

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.RandomRotation((-7.0, 7.0), fill=(1,)),

                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
from tqdm import tqdm

train_losses = []
test_losses = []
train_acc = []
test_acc = []

def train(model, device, train_loader, optimizer, epoch):
  model.train()
  pbar = tqdm(train_loader)
  correct = 0
  processed = 0
  for batch_idx, (data, target) in enumerate(pbar):
    # get samples
    data, target = data.to(device), target.to(device)

    # Init
    optimizer.zero_grad()
    # In PyTorch, we need to set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes. 
    # Because of this, when you start your training loop, ideally you should zero out the gradients so that you do the parameter update correctly.

    # Predict
    y_pred = model(data)

    # Calculate loss
    loss = F.nll_loss(y_pred, target)
    train_losses.append(loss)

    # Backpropagation
    loss.backward()
    optimizer.step()

    # Update pbar-tqdm
    
    pred = y_pred.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
    correct += pred.eq(target.view_as(pred)).sum().item()
    processed += len(data)

    pbar.set_description(desc= f'Loss={loss.item()} Batch_id={batch_idx} Accuracy={100*correct/processed:0.2f}')
    train_acc.append(100*correct/processed)

def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    test_acc.append(100. * correct / len(test_loader.dataset))

# %%
from torch.optim.lr_scheduler import StepLR

model =  Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)
scheduler = StepLR(optimizer, step_size=6, gamma=0.1)

EPOCHS = 40
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
    scheduler.step()
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]
# EPOCH: 0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Loss=0.07709074020385742 Batch_id=468 Accuracy=93.51: 100%|██████████| 469/469 [00:13<00:00, 34.31it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0706, Accuracy: 9786/10000 (97.86%)
#
# EPOCH: 1
# Loss=0.06966604292392731 Batch_id=468 Accuracy=98.17: 100%|██████████| 469/469 [00:13<00:00, 33.90it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0510, Accuracy: 9844/10000 (98.44%)
#
# EPOCH: 2
# Loss=0.02914717234671116 Batch_id=468 Accuracy=98.60: 100%|██████████| 469/469 [00:13<00:00, 33.56it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0358, Accuracy: 9895/10000 (98.95%)
#
# EPOCH: 3
# Loss=0.031473372131586075 Batch_id=468 Accuracy=98.79: 100%|██████████| 469/469 [00:13<00:00, 33.50it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0345, Accuracy: 9893/10000 (98.93%)
#
# EPOCH: 4
# Loss=0.03456384316086769 Batch_id=468 Accuracy=98.89: 100%|██████████| 469/469 [00:13<00:00, 33.63it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0312, Accuracy: 9909/10000 (99.09%)
#
# EPOCH: 5
# Loss=0.06937706470489502 Batch_id=468 Accuracy=98.97: 100%|██████████| 469/469 [00:13<00:00, 34.20it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0320, Accuracy: 9894/10000 (98.94%)
#
# EPOCH: 6
# Loss=0.009870399720966816 Batch_id=468 Accuracy=99.24: 100%|██████████| 469/469 [00:13<00:00, 33.54it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0222, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 7
# Loss=0.045822873711586 Batch_id=468 Accuracy=99.33: 100%|██████████| 469/469 [00:13<00:00, 33.76it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0213, Accuracy: 9932/10000 (99.32%)
#
# EPOCH: 8
# Loss=0.03388059511780739 Batch_id=468 Accuracy=99.31: 100%|██████████| 469/469 [00:14<00:00, 34.87it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0219, Accuracy: 9933/10000 (99.33%)
#
# EPOCH: 9
# Loss=0.04259582236409187 Batch_id=468 Accuracy=99.37: 100%|██████████| 469/469 [00:13<00:00, 33.63it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0212, Accuracy: 9939/10000 (99.39%)
#
# EPOCH: 10
# Loss=0.03716510906815529 Batch_id=468 Accuracy=99.42: 100%|██████████| 469/469 [00:14<00:00, 33.23it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0214, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 11
# Loss=0.01408220361918211 Batch_id=468 Accuracy=99.34: 100%|██████████| 469/469 [00:13<00:00, 33.65it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0214, Accuracy: 9932/10000 (99.32%)
#
# EPOCH: 12
# Loss=0.0039184787310659885 Batch_id=468 Accuracy=99.44: 100%|██████████| 469/469 [00:13<00:00, 35.81it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0206, Accuracy: 9936/10000 (99.36%)
#
# EPOCH: 13
# Loss=0.030350694432854652 Batch_id=468 Accuracy=99.41: 100%|██████████| 469/469 [00:13<00:00, 33.71it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0207, Accuracy: 9937/10000 (99.37%)
#
# EPOCH: 14
# Loss=0.0179943535476923 Batch_id=468 Accuracy=99.37: 100%|██████████| 469/469 [00:14<00:00, 32.74it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0210, Accuracy: 9935/10000 (99.35%)
#
# EPOCH: 15
# Loss=0.01022176444530487 Batch_id=468 Accuracy=99.40: 100%|██████████| 469/469 [00:13<00:00, 34.00it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0206, Accuracy: 9931/10000 (99.31%)
#
# EPOCH: 16
# Loss=0.022775908932089806 Batch_id=468 Accuracy=99.42: 100%|██████████| 469/469 [00:13<00:00, 33.55it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0211, Accuracy: 9935/10000 (99.35%)
#
# EPOCH: 17
# Loss=0.004854127764701843 Batch_id=468 Accuracy=99.45: 100%|██████████| 469/469 [00:14<00:00, 33.06it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0206, Accuracy: 9939/10000 (99.39%)
#
# EPOCH: 18
# Loss=0.00947840977460146 Batch_id=468 Accuracy=99.41: 100%|██████████| 469/469 [00:14<00:00, 33.25it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0207, Accuracy: 9936/10000 (99.36%)
#
# EPOCH: 19
# Loss=0.0179929006844759 Batch_id=468 Accuracy=99.43: 100%|██████████| 469/469 [00:14<00:00, 32.39it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0210, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 20
# Loss=0.03553624451160431 Batch_id=468 Accuracy=99.45: 100%|██████████| 469/469 [00:14<00:00, 33.45it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0205, Accuracy: 9937/10000 (99.37%)
#
# EPOCH: 21
# Loss=0.0061084977351129055 Batch_id=468 Accuracy=99.45: 100%|██████████| 469/469 [00:14<00:00, 32.87it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0208, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 22
# Loss=0.00892618764191866 Batch_id=468 Accuracy=99.44: 100%|██████████| 469/469 [00:14<00:00, 32.14it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0210, Accuracy: 9931/10000 (99.31%)
#
# EPOCH: 23
# Loss=0.0057595171965658665 Batch_id=468 Accuracy=99.44: 100%|██████████| 469/469 [00:14<00:00, 33.01it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0211, Accuracy: 9936/10000 (99.36%)
#
# EPOCH: 24
# Loss=0.03106333129107952 Batch_id=468 Accuracy=99.43: 100%|██████████| 469/469 [00:14<00:00, 32.83it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0207, Accuracy: 9936/10000 (99.36%)
#
# EPOCH: 25
# Loss=0.008937641978263855 Batch_id=468 Accuracy=99.43: 100%|██████████| 469/469 [00:14<00:00, 32.20it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0205, Accuracy: 9938/10000 (99.38%)
#
# EPOCH: 26
# Loss=0.014569195918738842 Batch_id=468 Accuracy=99.44: 100%|██████████| 469/469 [00:14<00:00, 32.79it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0207, Accuracy: 9936/10000 (99.36%)
#
# EPOCH: 27
# Loss=0.004604662302881479 Batch_id=468 Accuracy=99.45: 100%|██████████| 469/469 [00:14<00:00, 32.62it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0208, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 28
# Loss=0.01842769794166088 Batch_id=468 Accuracy=99.45: 100%|██████████| 469/469 [00:13<00:00, 33.51it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0207, Accuracy: 9931/10000 (99.31%)
#
# EPOCH: 29
# Loss=0.0057860263623297215 Batch_id=468 Accuracy=99.42: 100%|██████████| 469/469 [00:14<00:00, 32.64it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0210, Accuracy: 9935/10000 (99.35%)
#
# EPOCH: 30
# Loss=0.013077561743557453 Batch_id=468 Accuracy=99.47: 100%|██████████| 469/469 [00:14<00:00, 33.38it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0210, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 31
# Loss=0.00808298122137785 Batch_id=468 Accuracy=99.45: 100%|██████████| 469/469 [00:14<00:00, 33.38it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0208, Accuracy: 9936/10000 (99.36%)
#
# EPOCH: 32
# Loss=0.013194605708122253 Batch_id=468 Accuracy=99.45: 100%|██████████| 469/469 [00:13<00:00, 35.08it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0208, Accuracy: 9931/10000 (99.31%)
#
# EPOCH: 33
# Loss=0.038959164172410965 Batch_id=468 Accuracy=99.42: 100%|██████████| 469/469 [00:14<00:00, 32.45it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0210, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 34
# Loss=0.04019795358181 Batch_id=468 Accuracy=99.44: 100%|██████████| 469/469 [00:14<00:00, 33.50it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0208, Accuracy: 9930/10000 (99.30%)
#
# EPOCH: 35
# Loss=0.031464044004678726 Batch_id=468 Accuracy=99.41: 100%|██████████| 469/469 [00:14<00:00, 33.36it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0211, Accuracy: 9932/10000 (99.32%)
#
# EPOCH: 36
# Loss=0.013918489217758179 Batch_id=468 Accuracy=99.43: 100%|██████████| 469/469 [00:14<00:00, 33.49it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0207, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 37
# Loss=0.007095014210790396 Batch_id=468 Accuracy=99.38: 100%|██████████| 469/469 [00:14<00:00, 32.76it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0208, Accuracy: 9931/10000 (99.31%)
#
# EPOCH: 38
# Loss=0.005352839827537537 Batch_id=468 Accuracy=99.42: 100%|██████████| 469/469 [00:14<00:00, 34.51it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0207, Accuracy: 9937/10000 (99.37%)
#
# EPOCH: 39
# Loss=0.011256103403866291 Batch_id=468 Accuracy=99.46: 100%|██████████| 469/469 [00:14<00:00, 33.37it/s]
# Test set: Average loss: 0.0209, Accuracy: 9935/10000 (99.35%)

# %%
train_losses_nm = []
for loss in train_losses:
   loss_value = loss.detach().cpu().numpy()
   train_losses_nm.append(loss_value) 
print("train_losses list: " + str(train_losses_nm))
print("test_losses list: " + str(test_losses))
print("train_acc list: " + str(train_acc))
print("test_acc list: " + str(test_acc))
# Out:
# train_losses list: [array(2.312329, dtype=float32), array(2.3009095, dtype=float32), array(2.251356, dtype=float32), array(2.211661, dtype=float32), array(2.1234045, dtype=float32), array(2.0772243, dtype=float32), array(2.0133214, dtype=float32), array(2.002228, dtype=float32), array(1.9659117, dtype=float32), array(1.8275559, dtype=float32), array(1.8964913, dtype=float32), array(1.7645109, dtype=float32), array(1.6486053, dtype=float32), array(1.7451016, dtype=float32), array(1.6595074, dtype=float32), array(1.5526394, dtype=float32), array(1.5359745, dtype=float32), array(1.4839152, dtype=float32), array(1.4739761, dtype=float32), array(1.3672315, dtype=float32), array(1.295756, dtype=float32), array(1.2833457, dtype=float32), array(1.2349474, dtype=float32), array(1.1783025, dtype=float32), array(1.0722859, dtype=float32), array(1.0030398, dtype=float32), array(1.0116764, dtype=float32), array(0.92235655, dtype=float32), array(0.92123675, dtype=float32), array(1.0083252, dtype=float32), array(0.84612954, dtype=float32), array(0.8283327, dtype=float32), array(0.797828, dtype=float32), array(0.77497244, dtype=float32), array(0.6821411, dtype=float32), array(0.62193507, dtype=float32), array(0.60531735, dtype=float32), array(0.64883333, dtype=float32), array(0.6175392, dtype=float32), array(0.5584944, dtype=float32), array(0.4782988, dtype=float32), array(0.5959169, dtype=float32), array(0.5733791, dtype=float32), array(0.50718606, dtype=float32), array(0.4670074, dtype=float32), array(0.5874062, dtype=float32), array(0.3925184, dtype=float32), array(0.47357416, dtype=float32), array(0.44154683, dtype=float32), array(0.32401216, dtype=float32), array(0.3291376, dtype=float32), array(0.34429708, dtype=float32), array(0.3303932, dtype=float32), array(0.2987822, dtype=float32), array(0.26612312, dtype=float32), array(0.34220257, dtype=float32), array(0.42806807, dtype=float32), array(0.3850778, dtype=float32), array(0.34625682, dtype=float32), array(0.23321304, dtype=float32), array(0.28725433, dtype=float32), array(0.24192163, dtype=float32), array(0.26440072, dtype=float32), array(0.17418626, dtype=float32), array(0.2696161, dtype=float32), array(0.2455469, dtype=float32), array(0.20282751, dtype=float32), array(0.34621984, dtype=float32), array(0.24806738, dtype=float32), array(0.23750532, dtype=float32), array(0.2614385, dtype=float32), array(0.26116475, dtype=float32), array(0.27333775, dtype=float32), array(0.188288, dtype=float32), array(0.20593461, dtype=float32), array(0.2237033, dtype=float32), array(0.31348348, dtype=float32), array(0.27041706, dtype=float32), array(0.18039072, dtype=float32), array(0.30413005, dtype=float32), array(0.16453663, dtype=float32), array(0.21193464, dtype=float32), array(0.14135107, dtype=float32), array(0.24771988, dtype=float32), array(0.13379739, dtype=float32), array(0.2037318, dtype=float32), array(0.23172943, dtype=float32), array(0.25527915, dtype=float32), array(0.14308472, dtype=float32), array(0.17891681, dtype=float32), array(0.20745312, dtype=float32), array(0.18814893, dtype=float32), array(0.20924571, dtype=float32), array(0.24656527, dtype=float32), array(0.20149511, dtype=float32), array(0.22793646, dtype=float32), array(0.2710038, dtype=float32), array(0.20688394, dtype=float32), array(0.10908956, dtype=float32), array(0.1546085, dtype=float32), array(0.23723903, dtype=float32), array(0.2778374, dtype=float32), array(0.22723965, dtype=float32), array(0.15634246, dtype=float32), array(0.17233646, dtype=float32), array(0.2944181, dtype=float32), array(0.22640002, dtype=float32), array(0.19129553, dtype=float32), array(0.20804927, dtype=float32), array(0.22892661, dtype=float32), array(0.12164891, dtype=float32), array(0.15753531, dtype=float32), array(0.20944989, dtype=float32), array(0.23494504, dtype=float32), array(0.17153671, dtype=float32), array(0.14689125, dtype=float32), array(0.19214368, dtype=float32), array(0.19212502, dtype=float32), array(0.15069535, dtype=floa ...
# test_losses list: [0.07057390615940094, 0.05096633114814758, 0.03583045179843902, 0.034494192242622373, 0.03118434488773346, 0.03195482161045075, 0.02222758071422577, 0.021300032138824462, 0.021855894827842712, 0.021195232725143433, 0.021389730238914488, 0.021371151733398437, 0.02060559847354889, 0.020669017601013185, 0.020962862658500673, 0.020587685918807982, 0.0211436265707016, 0.020583196449279785, 0.02074256591796875, 0.020971233201026916, 0.02049741244316101, 0.02082614948749542, 0.02100419285297394, 0.021072479343414306, 0.02070101125240326, 0.020527932024002077, 0.020676571130752563, 0.020811376953125, 0.020740619540214538, 0.020984193658828736, 0.021007053971290587, 0.0207799742937088, 0.020849908757209778, 0.020977235889434814, 0.02082942314147949, 0.02111052899360657, 0.020712174940109254, 0.020783621430397033, 0.02074474356174469, 0.020946257996559144]
# train_acc list: [10.9375, 14.0625, 15.364583333333334, 16.9921875, 18.90625, 22.135416666666668, 24.665178571428573, 26.46484375, 27.604166666666668, 30.234375, 31.53409090909091, 33.268229166666664, 35.33653846153846, 35.99330357142857, 37.1875, 38.232421875, 39.338235294117645, 40.755208333333336, 41.776315789473685, 43.046875, 44.49404761904762, 45.45454545454545, 46.46739130434783, 47.493489583333336, 48.625, 49.609375, 50.636574074074076, 51.89732142857143, 52.88254310344828, 53.59375, 54.586693548387096, 55.3466796875, 56.17897727272727, 56.916360294117645, 57.700892857142854, 58.615451388888886, 59.501689189189186, 60.135690789473685, 60.75721153846154, 61.4453125, 62.19512195121951, 62.741815476190474, 63.35392441860465, 63.90269886363637, 64.47916666666667, 64.94565217391305, 65.50864361702128, 66.04817708333333, 66.56568877551021, 67.0625, 67.57046568627452, 68.07391826923077, 68.51415094339623, 68.96701388888889, 69.44602272727273, 69.83816964285714, 70.20285087719299, 70.52801724137932, 70.86864406779661, 71.25, 71.58043032786885, 71.95060483870968, 72.27182539682539, 72.65625, 72.95673076923077, 73.25994318181819, 73.60074626865672, 73.828125, 74.12817028985508, 74.39732142857143, 74.65889084507042, 74.92404513888889, 75.17123287671232, 75.47508445945945, 75.72916666666667, 75.98684210526316, 76.21753246753246, 76.41225961538461, 76.67128164556962, 76.845703125, 77.08333333333333, 77.28658536585365, 77.5414156626506, 77.71577380952381, 77.94117647058823, 78.14316860465117, 78.34051724137932, 78.5067471590909, 78.72191011235955, 78.90625, 79.0779532967033, 79.25441576086956, 79.42708333333333, 79.56283244680851, 79.74506578947368, 79.92350260416667, 80.06604381443299, 80.22161989795919, 80.40561868686869, 80.546875, 80.67759900990099, 80.7904411764706, 80.8935072815534, 81.04717548076923, 81.19791666666667, 81.30896226415095, 81.41793224299066, 81.55381944444444, 81.68004587155963, 81.78267045454545, 81.93271396396396, 82.05915178571429, 82.16261061946902, 82.25054824561404, 82.37771739130434, 82.49595905172414, 82.59214743589743, 82.70656779661017, 82.82563025210084, 82.94270833333333, 83.03848140495867, 83.15829918032787, 83.26981707317073, 83.37323588709677, 83.48125, 83.5813492063492, 83.63681102362204, 83.72802734375, 83.82388565891473, 83.91826923076923, 84.02910305343511, 84.13825757575758, 84.23402255639098, 84.34001865671642, 84.4386574074074, 84.51861213235294, 84.5973996350365, 84.66938405797102, 84.74033273381295, 84.82142857142857, 84.90691489361703, 84.99669894366197, 85.08522727272727, 85.18337673611111, 85.24245689655173, 85.31142979452055, 85.39009353741497, 85.46241554054055, 85.5442533557047, 85.61458333333333, 85.69950331125828, 85.76274671052632, 85.82516339869281, 85.88676948051948, 85.96270161290323, 86.0176282051282, 86.10171178343948, 86.1748417721519, 86.25196540880503, 86.318359375, 86.38878105590062, 86.45833333333333, 86.5174463190184, 86.56154725609755, 86.61931818181819, 86.69051204819277, 86.7374625748503, 86.8071056547619, 86.86667899408285, 86.93014705882354, 86.98830409356725, 87.0594113372093, 87.11614884393063, 87.16325431034483, 87.21428571428571, 87.28249289772727, 87.31903248587571, 87.37271769662921, 87.40834497206704, 87.45659722222223, 87.49568370165746, 87.5472184065934, 87.59818989071039, 87.64011548913044, 87.67736486486487, 87.71001344086021, 87.72142379679144, 87.77426861702128, 87.83068783068784, 87.8782894736842, 87.92130235602095, 87.9638671875, 88.01003886010362, 88.04768041237114, 88.10096153846153, 88.14971301020408, 88.19796954314721, 88.24179292929293, 88.28125, 88.3046875, 88.35509950248756, 88.37793935643565, 88.41594827586206, 88.45358455882354, 88.48323170731707, 88.5277609223301, 88.57563405797102, 88.61929086538461, 88.66626794258373, 88.7016369047619, 88.74777843601896, 88.78242924528301, 88.82409037558685, 88.85806074766356, 88.89171511627907, 88.93229166666667, 88.96529377880184, 88.99799311926606, 89.03752853881278, 89.06960227272727, 89.108455882352 ...
# test_acc list: [97.86, 98.44, 98.95, 98.93, 99.09, 98.94, 99.34, 99.32, 99.33, 99.39, 99.34, 99.32, 99.36, 99.37, 99.35, 99.31, 99.35, 99.39, 99.36, 99.34, 99.37, 99.34, 99.31, 99.36, 99.36, 99.38, 99.36, 99.34, 99.31, 99.35, 99.34, 99.36, 99.31, 99.34, 99.3, 99.32, 99.34, 99.31, 99.37, 99.35]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2,2,figsize=(15,10))
axs[0, 0].plot(train_losses)
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_acc)
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_acc)
axs[1, 1].set_title("Test Accuracy")
# Out:
# Text(0.5, 1.0, 'Test Accuracy')

# %%
incorrect_image_list =[]
predicted_label_list =[]
correct_label_list = []
with torch.no_grad():
    for (i, [data, target]) in enumerate(test_loader):
        data, target = data.to(device), target.to(device)
        output = model(data)
        pred = output.argmax(dim=1, keepdim=True).squeeze(1)         
        idxs_mask = (pred !=  target).view(-1)
        img_nm = data[idxs_mask].cpu().numpy()
        img_nm = img_nm.reshape(img_nm.shape[0], 28, 28)
        if img_nm.shape[0] > 0:
            img_list = [img_nm[i] for i in range(img_nm.shape[0])]
            incorrect_image_list.extend(img_list)
            predicted_label_list.extend(pred[idxs_mask].cpu().numpy())
            correct_label_list.extend(target[idxs_mask].cpu().numpy())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %%
plt.figure(figsize=(15,15))
columns = 5
i= 0
# Display the list of 25 misclassified images
for index, image in enumerate(incorrect_image_list) :
    ax = plt.subplot(5, 5, i+1)
    ax.set_title("Actual: " + str(correct_label_list[index]) + ", Predicted: " + str(predicted_label_list[index]))
    ax.axis('off')
    plt.imshow(image)
    i +=1
    if i==25:
        break
